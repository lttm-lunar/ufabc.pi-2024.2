# %%
import math

x = float(input())

f = (5 * math.log(2 * (x ** 2))) / math.sqrt(30 - x ** 2)
g = (7 * x **2 * math.sin(x) * math.cos(x)) / math.sqrt(3 * x + 8)

print("{:.2f} {:.2f}".format(f,g))
# Out:
# 1.2
# 0.99 1.00
